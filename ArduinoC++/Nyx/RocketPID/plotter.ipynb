# %%
import pandas as pd
df = pd.read_csv('codeOutput1.csv')
df
# Out:
#           t    w3  compute  cantAngle  cantAngleM  Unnamed: 5
# 0      4.30 -0.37     0.11        0.0      1500.0         NaN
# 1      4.31  0.33    -0.09        0.0      1500.0         NaN
# 2      4.32  0.98    -0.29        0.0      1500.0         NaN
# 3      4.33  1.61    -0.48        0.0      1500.0         NaN
# 4      4.34  2.20    -0.66       -1.0      1485.0         NaN
# ...     ...   ...      ...        ...         ...         ...
# 1419  18.49 -0.00    -4.50       -4.0      1440.0         NaN
# 1420  18.50 -0.00    -4.50       -4.0      1440.0         NaN
# 1421  18.51 -0.00    -4.50       -5.0      1425.0         NaN
# 1422  18.52 -0.00    -4.50       -5.0      1425.0         NaN
# 1423  18.53 -0.00    -4.50       -4.0      1440.0         NaN
#
# [1424 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib widget

plt.plot(df['t'],df['w3'])
plt.plot(df['t'],df['cantAngle'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
