# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('SDteste5.txt')
df
# Out:
#       acx   acy    acz   tmp   gyx  gyy  gyz  filtrado
# 0    2248  3224 -19584 -1712  3033 -255  -82      0.00
# 1    2328  3160 -19564 -1648  3024 -263  -94      0.00
# 2    2368  3232 -19604 -1680  3054 -227  -86      0.00
# 3    2252  3156 -19688 -1648  3056 -236  -90      0.00
# 4    2260  3236 -19648 -1680  3026 -239 -110      0.00
# ..    ...   ...    ...   ...   ...  ...  ...       ...
# 708  1740  3176 -19508 -1696  4036 -123 -655    343.21
# 709  1680  2768 -19700 -1664  4018 -166 -297    -51.18
# 710  2076  3172 -19716 -1664  3799 -313   84   -459.24
# 711  1532  2652 -19524 -1664  3680  -52  507   -699.02
# 712  1920  2256 -19764 -1664  3683 -158  288   -746.47
#
# [713 rows x 8 columns]

# %%
acx = df['acx']
plt.plot(acx)
acy = df['acy']
plt.plot(acy)
acz = df['acz']
plt.plot(acz)
plt.grid()
plt.xlabel('interations')
plt.ylabel('GyZ')
# Out:
# Text(0, 0.5, 'GyZ')

# %%
gyz = df['gyz']
filtrado = df['filtrado']
plt.plot(gyz)
plt.plot(filtrado)
plt.grid()
plt.xlabel('interations')
plt.ylabel('GyZ')
# Out:
# Text(0, 0.5, 'GyZ')

# %%
gyx = df['gyx']
plt.plot(gyx)
plt.grid()
plt.xlabel('interations')
plt.ylabel('GyZ')
# Out:
# Text(0, 0.5, 'GyZ')

# %%
gyy = df['gyy']
plt.plot(gyy)
plt.grid()
plt.xlabel('interations')
plt.ylabel('GyZ')
# Out:
# Text(0, 0.5, 'GyZ')
